# %%
from pathlib import Path
import os
import pandas as pd
import matplotlib.pyplot as plt
path = Path("./Data")
print(path.parent)
DF1 = pd.read_excel("./Data/Electron_Water.xlsx")
#DF2=pd.read_excel("./Data/Proton_Water.xlsx")
plt.plot(DF1.Energy
,DF1.Collision
, color='r', linewidth=1)
#plt.plot(DF2.Energy,DF2.TotalStp, color='r', linewidth=1)
plt.xlabel('Energy (MeV)')
plt.ylabel('Collision Stp. Pow. MeV cm2/g')
plt.title('Collisional stopping power for electron in water')
#plt.legend(['Electron','Proton'])
#plt.ylim(0,2.5)
#plt.xlim(0,20)
plt.xscale("log")
plt.yscale("log")
plt.savefig("plot1.pdf", bbox_inches='tight')
plt.show()
DF1
# Out:
# .
#      Energy  Collision  Radiative Stp. Pow. MeV cm2/g  TotalStp      CSDA  \
# 0    0.0100     22.560                       0.003898    22.560  0.000251
# 1    0.0125     18.970                       0.003927    18.980  0.000373
# 2    0.0150     16.470                       0.003944    16.470  0.000515
# 3    0.0175     14.610                       0.003955    14.610  0.000676
# 4    0.0200     13.170                       0.003963    13.180  0.000857
# 5    0.0250     11.090                       0.003974    11.100  0.001272
# 6    0.0300      9.653                       0.003984     9.657  0.001756
# 7    0.0350      8.592                       0.003994     8.596  0.002306
# 8    0.0400      7.777                       0.004005     7.781  0.002919
# 9    0.0450      7.130                       0.004018     7.134  0.003591
# 10   0.0500      6.603                       0.004031     6.607  0.004320
# 11   0.0550      6.166                       0.004046     6.170  0.005103
# ...

# %%
from pathlib import Path
import os
import pandas as pd
import matplotlib.pyplot as plt
path = Path("./Data")
print(path.parent)
#DF2 = pd.read_excel("./Data/Electron_Water.xlsx")
DF2=pd.read_excel("./Data/Proton_Water.xlsx")
plt.plot(DF2.Energy
,DF2.Nuclear
, color='g', linewidth=1)
#plt.plot(DF2.Energy,DF2.TotalStp, color='r', linewidth=1)
plt.xlabel('Energy (MeV)')
plt.ylabel('Total Stp. Pow. MeV cm2/g')
plt.ylabel('Nuclear collision Stp. Pow. MeV cm2/g')
#plt.legend(['Electron','Proton'])
#plt.ylim(0,2.5)
#plt.xlim(0,20)
plt.title('Collisional stopping (nuclear) power for proton in water')
plt.xscale("log")
plt.yscale("log")
plt.savefig("plot2.pdf", bbox_inches='tight')
plt.show()
DF2
# Out:
# .
#          Energy  Electron    Nuclear  TotalStp         CSDA  \
# 0        0.0010   133.700  43.150000   176.900     0.000006
# 1        0.0015   163.800  34.600000   198.400     0.000009
# 2        0.0020   189.100  29.270000   218.400     0.000011
# 3        0.0025   211.400  25.570000   237.000     0.000014
# 4        0.0030   231.600  22.810000   254.400     0.000016
# ..          ...       ...        ...       ...          ...
# 127   6000.0000     2.052   0.000061     2.052  2787.000000
# 128   7000.0000     2.072   0.000053     2.072  3272.000000
# 129   8000.0000     2.091   0.000047     2.091  3752.000000
# 130   9000.0000     2.109   0.000042     2.109  4228.000000
# 131  10000.0000     2.126   0.000038     2.126  4700.000000
#
#      Projected Range g/cm2  Detour Factor
# 0                 0.000003         0.4555
# 1                 0.000004         0.4906
# 2                 0.000006         0.5197
# 3                 0.000007         0.5440
# ...

# %%
from pathlib import Path
import os
import pandas as pd
import matplotlib.pyplot as plt
path = Path("./Data")
print(path.parent)
#DF2 = pd.read_excel("./Data/Electron_Water.xlsx")
DF2=pd.read_excel("./Data/Proton_Water.xlsx")
plt.plot(DF2.Energy
,DF2.Electron
, color='black', linewidth=1)
#plt.plot(DF2.Energy,DF2.TotalStp, color='r', linewidth=1)
plt.xlabel('Energy (MeV)')
plt.ylabel('Electronic Stp. Pow. MeV cm2/g')
plt.title('Collisional stopping (Electronic) power for proton in water')

#plt.legend(['Electron','Proton'])
#plt.ylim(0,2.5)
#plt.xlim(0,20)
plt.xscale("log")
plt.yscale("log")
plt.savefig("plot3.pdf", bbox_inches='tight')
plt.show()
DF2
# Out:
# .
#          Energy  Electron    Nuclear  TotalStp         CSDA  \
# 0        0.0010   133.700  43.150000   176.900     0.000006
# 1        0.0015   163.800  34.600000   198.400     0.000009
# 2        0.0020   189.100  29.270000   218.400     0.000011
# 3        0.0025   211.400  25.570000   237.000     0.000014
# 4        0.0030   231.600  22.810000   254.400     0.000016
# ..          ...       ...        ...       ...          ...
# 127   6000.0000     2.052   0.000061     2.052  2787.000000
# 128   7000.0000     2.072   0.000053     2.072  3272.000000
# 129   8000.0000     2.091   0.000047     2.091  3752.000000
# 130   9000.0000     2.109   0.000042     2.109  4228.000000
# 131  10000.0000     2.126   0.000038     2.126  4700.000000
#
#      Projected Range g/cm2  Detour Factor
# 0                 0.000003         0.4555
# 1                 0.000004         0.4906
# 2                 0.000006         0.5197
# 3                 0.000007         0.5440
# ...

# %% [markdown]
# # CSDA of electron in water

# %%
from pathlib import Path
import os
import pandas as pd
import matplotlib.pyplot as plt
path = Path("./Data")
print(path.parent)
DF1 = pd.read_excel("./Data/Electron_Water.xlsx")
#DF2=pd.read_excel("./Data/Proton_Water.xlsx")
plt.scatter(DF1.Energy
,DF1.CSDA
, color='g', linewidth=1)
#plt.plot(DF2.Energy,DF2.TotalStp, color='r', linewidth=1)
plt.xlabel('Energy (MeV)')
plt.ylabel('CSDA Range(g/cm^2)')
plt.title('CSDA of electron in water')
#plt.legend(['Electron','Proton'])
#plt.ylim(0,2.5)
#plt.xlim(0,20)
plt.xscale("log")
plt.yscale("log")
plt.savefig("plot4.pdf", bbox_inches='tight')
plt.show()
DF1
# Out:
# .
#      Energy  Collision  Radiative Stp. Pow. MeV cm2/g  TotalStp      CSDA  \
# 0    0.0100     22.560                       0.003898    22.560  0.000251
# 1    0.0125     18.970                       0.003927    18.980  0.000373
# 2    0.0150     16.470                       0.003944    16.470  0.000515
# 3    0.0175     14.610                       0.003955    14.610  0.000676
# 4    0.0200     13.170                       0.003963    13.180  0.000857
# 5    0.0250     11.090                       0.003974    11.100  0.001272
# 6    0.0300      9.653                       0.003984     9.657  0.001756
# 7    0.0350      8.592                       0.003994     8.596  0.002306
# 8    0.0400      7.777                       0.004005     7.781  0.002919
# 9    0.0450      7.130                       0.004018     7.134  0.003591
# 10   0.0500      6.603                       0.004031     6.607  0.004320
# 11   0.0550      6.166                       0.004046     6.170  0.005103
# ...

# %% [markdown]
# # CDSA of the proton in water

# %%
from pathlib import Path
import os
import pandas as pd
import matplotlib.pyplot as plt
path = Path("./Data")
print(path.parent)
DF2 = pd.read_excel("./Data/Proton_Water.xlsx")
#DF2=pd.read_excel("./Data/Proton_Water.xlsx")
plt.scatter(DF2.Energy
,DF2.CSDA
, color='orange', linewidth=1)
#plt.plot(DF2.Energy,DF2.TotalStp, color='r', linewidth=1)
plt.xlabel('Energy (MeV)')
plt.ylabel('CSDA Range(g/cm^2)')
plt.title('CSDA of proton in water')
#plt.legend(['Electron','Proton'])
#plt.ylim(0,2.5)
#plt.xlim(0,20)
plt.xscale("log")
plt.yscale("log")
plt.savefig("plot5.pdf", bbox_inches='tight')
plt.show()
DF2
# Out:
# .
#          Energy  Electron    Nuclear  TotalStp         CSDA  \
# 0        0.0010   133.700  43.150000   176.900     0.000006
# 1        0.0015   163.800  34.600000   198.400     0.000009
# 2        0.0020   189.100  29.270000   218.400     0.000011
# 3        0.0025   211.400  25.570000   237.000     0.000014
# 4        0.0030   231.600  22.810000   254.400     0.000016
# ..          ...       ...        ...       ...          ...
# 127   6000.0000     2.052   0.000061     2.052  2787.000000
# 128   7000.0000     2.072   0.000053     2.072  3272.000000
# 129   8000.0000     2.091   0.000047     2.091  3752.000000
# 130   9000.0000     2.109   0.000042     2.109  4228.000000
# 131  10000.0000     2.126   0.000038     2.126  4700.000000
#
#      Projected Range g/cm2  Detour Factor
# 0                 0.000003         0.4555
# 1                 0.000004         0.4906
# 2                 0.000006         0.5197
# 3                 0.000007         0.5440
# ...
